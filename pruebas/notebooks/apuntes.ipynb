# %%
import random
import numpy as np

# %%
# CONSATNTS:

eslora_4=4
eslora_3=3
eslora_2=2
eslora_1=1

barco_e4_1=eslora_4
barco_e3_1=eslora_3
barco_e3_2=eslora_3
barco_e3_3=eslora_3
barco_e2_1=eslora_2
barco_e2_2=eslora_2
barco_e2_3=eslora_2
barco_e1_1=eslora_1
barco_e1_2=eslora_1
barco_e1_3=eslora_1
barco_e1_4=eslora_1


diccionario_barcos={'barco_e4_1':eslora_4,
                    'barco_e3_1':eslora_3,
                    'barco_e3_2':eslora_3,
                    'barco_e2_1':eslora_2,
                    'barco_e2_2':eslora_2,
                    'barco_e2_3':eslora_2,
                    'barco_e1_1':eslora_1,
                    'barco_e1_2':eslora_1,
                    'barco_e1_3':eslora_1,
                    'barco_e1_4':eslora_1,}

tablero_jugador_barcos = np.full(fill_value=' ', shape=(10, 10))
tablero_jugador_disparos = np.full(fill_value=' ', shape=(10, 10))
tablero_maquina_barcos = np.full(fill_value=' ', shape=(10, 10))
tablero_maquina_disparos = np.full(fill_value=' ', shape=(10, 10))

# %%
# UTILS:

# %%
# Funcion colocar barcos:
def coloc_barcos(tablero, eslora):
    while True:
        # 'N' - 'S' - 'E' - 'O'
        orient = random.choice(['N', 'S', 'E', 'O'])  
        print(orient)
        
        # Posicion inicial del barco, np.array con dos valores, te da las primeras coordenadas
        current_pos = np.random.randint(10, size = 2)
        print('Posición inicial:',current_pos)
        
        fila = current_pos[0]
        print('Fila:', fila)
        col = current_pos[1]
        print('Columna:', col)
        
        # Recogemos las 4 posiciones colindantes a current_pos
        coors_posiN = tablero[fila:fila - eslora:-1, col]
        coors_posiE = tablero[fila, col: col + eslora]
        coors_posiS = tablero[fila:fila + eslora, col]
        coors_posiO = tablero[fila, col: col - eslora:-1]
        
        # Comprobamos si esas posiciones son validas
        # Orientacion Norte
        if orient == 'N' and 0 <= fila - eslora < 10 and 'O' not in coors_posiN:
            tablero[fila:fila - eslora:-1, col] = 'O'
            break

        # Orientacion Este
        elif orient == 'E' and 0 <= col + eslora < 10 and 'O' not in coors_posiE:
            tablero[fila, col: col + eslora] = 'O'
            break

        # Orientacion Sur
        elif orient == 'S' and 0 <= fila + eslora < 10 and 'O' not in coors_posiS:
            tablero[fila:fila + eslora, col] = 'O'
            break

        # Orientacion Oeste
        elif orient == 'O' and 0 <= col - eslora < 10 and 'O' not in coors_posiO:
            tablero[fila, col: col - eslora:-1] = 'O'
            break

        # No cumple con las dimensiones del tablero, o hay un barco ahi
        # Probamos con otra coordenada
        else:
            continue
    return tablero

# %%
# Funncion colocar 1 barco de eslora 4:
def coloc_barcos_e4(tablero):
    eslora=4
    while True:
        # 'N' - 'S' - 'E' - 'O'
        orient = random.choice(['N', 'S', 'E', 'O'])  
        print(orient)
        
        # Posicion inicial del barco, np.array con dos valores, te da las primeras coordenadas
        current_pos = np.random.randint(10, size = 2)
        print('Posición inicial:',current_pos)
        
        fila = current_pos[0]
        print('Fila:', fila)
        col = current_pos[1]
        print('Columna:', col)
        
        # Recogemos las 4 posiciones colindantes a current_pos
        coors_posiN = tablero[fila:fila - eslora:-1, col]
        coors_posiE = tablero[fila, col: col + eslora]
        coors_posiS = tablero[fila:fila + eslora, col]
        coors_posiO = tablero[fila, col: col - eslora:-1]
        
        # Comprobamos si esas posiciones son validas
        # Orientacion Norte
        if orient == 'N' and 0 <= fila - eslora < 10 and 'O' not in coors_posiN:
            tablero[fila:fila - eslora:-1, col] = 'O'
            break

        # Orientacion Este
        elif orient == 'E' and 0 <= col + eslora < 10 and 'O' not in coors_posiE:
            tablero[fila, col: col + eslora] = 'O'
            break

        # Orientacion Sur
        elif orient == 'S' and 0 <= fila + eslora < 10 and 'O' not in coors_posiS:
            tablero[fila:fila + eslora, col] = 'O'
            break

        # Orientacion Oeste
        elif orient == 'O' and 0 <= col - eslora < 10 and 'O' not in coors_posiO:
            tablero[fila, col: col - eslora:-1] = 'O'
            break

        # No cumple con las dimensiones del tablero, o hay un barco ahi
        # Probamos con otra coordenada
        else:
            continue
    return tablero

coloc_barcos_e4(tablero_jugador_barcos)
# Out:
# N
# Posición inicial: [6 0]
# Fila: 6
# Columna: 0
# array([[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']], dtype='<U1')

# %%
# Funncion colocar 2 barcos de eslora 3:
def coloc_barcos_e3(tablero):
    eslora=3
    i=0
    while i<2:
        # 'N' - 'S' - 'E' - 'O'
        orient = random.choice(['N', 'S', 'E', 'O'])  
        print(orient)
        
        # Posicion inicial del barco, np.array con dos valores, te da las primeras coordenadas
        current_pos = np.random.randint(10, size = 2)
        print('Posición inicial:',current_pos)
        
        fila = current_pos[0]
        print('Fila:', fila)
        col = current_pos[1]
        print('Columna:', col)
        
        # Recogemos las 4 posiciones colindantes a current_pos
        coors_posiN = tablero[fila:fila - eslora:-1, col]
        coors_posiE = tablero[fila, col: col + eslora]
        coors_posiS = tablero[fila:fila + eslora, col]
        coors_posiO = tablero[fila, col: col - eslora:-1]
        
        # Comprobamos si esas posiciones son validas
        # Orientacion Norte
        if orient == 'N' and 0 <= fila - eslora < 10 and 'O' not in coors_posiN:
            tablero[fila:fila - eslora:-1, col] = 'O'
            i+=1
            

        # Orientacion Este
        elif orient == 'E' and 0 <= col + eslora < 10 and 'O' not in coors_posiE:
            tablero[fila, col: col + eslora] = 'O'
            i+=1

        # Orientacion Sur
        elif orient == 'S' and 0 <= fila + eslora < 10 and 'O' not in coors_posiS:
            tablero[fila:fila + eslora, col] = 'O'
            i+=1

        # Orientacion Oeste
        elif orient == 'O' and 0 <= col - eslora < 10 and 'O' not in coors_posiO:
            tablero[fila, col: col - eslora:-1] = 'O'
            i+=1

        # No cumple con las dimensiones del tablero, o hay un barco ahi
        # Probamos con otra coordenada
        else:
            continue
    return tablero


coloc_barcos_e3(tablero_jugador_barcos)
# Out:
# O
# Posición inicial: [8 8]
# Fila: 8
# Columna: 8
# E
# Posición inicial: [9 5]
# Fila: 9
# Columna: 5
# array([[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O', ' '],
#        [' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O', ' ', ' ']], dtype='<U1')

# %%
# Funncion colocar 3 barcos de eslora 2:
def coloc_barcos_e2(tablero):
    eslora=2
    i=0
    while i<3:
        # 'N' - 'S' - 'E' - 'O'
        orient = random.choice(['N', 'S', 'E', 'O'])  
        print(orient)
        
        # Posicion inicial del barco, np.array con dos valores, te da las primeras coordenadas
        current_pos = np.random.randint(10, size = 2)
        print('Posición inicial:',current_pos)
        
        fila = current_pos[0]
        print('Fila:', fila)
        col = current_pos[1]
        print('Columna:', col)
        
        # Recogemos las 4 posiciones colindantes a current_pos
        coors_posiN = tablero[fila:fila - eslora:-1, col]
        coors_posiE = tablero[fila, col: col + eslora]
        coors_posiS = tablero[fila:fila + eslora, col]
        coors_posiO = tablero[fila, col: col - eslora:-1]
        
        # Comprobamos si esas posiciones son validas
        # Orientacion Norte
        if orient == 'N' and 0 <= fila - eslora < 10 and 'O' not in coors_posiN:
            tablero[fila:fila - eslora:-1, col] = 'O'
            i+=1
            

        # Orientacion Este
        elif orient == 'E' and 0 <= col + eslora < 10 and 'O' not in coors_posiE:
            tablero[fila, col: col + eslora] = 'O'
            i+=1

        # Orientacion Sur
        elif orient == 'S' and 0 <= fila + eslora < 10 and 'O' not in coors_posiS:
            tablero[fila:fila + eslora, col] = 'O'
            i+=1

        # Orientacion Oeste
        elif orient == 'O' and 0 <= col - eslora < 10 and 'O' not in coors_posiO:
            tablero[fila, col: col - eslora:-1] = 'O'
            i+=1

        # No cumple con las dimensiones del tablero, o hay un barco ahi
        # Probamos con otra coordenada
        else:
            continue
    return tablero


coloc_barcos_e2(tablero_jugador_barcos)
# Out:
# S
# Posición inicial: [6 9]
# Fila: 6
# Columna: 9
# S
# Posición inicial: [8 9]
# Fila: 8
# Columna: 9
# E
# Posición inicial: [2 2]
# Fila: 2
# Columna: 2
# O
# Posición inicial: [8 8]
# Fila: 8
# Columna: 8
# S
# Posición inicial: [3 3]
# Fila: 3
# Columna: 3
# array([[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', 'O', 'O', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', 'O', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', 'O', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'O'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'O'],
#        [' ', ' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O', ' '],
#        [' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O', ' ', ' ']], dtype='<U1')

# %%
# Funncion colocar 3 barcos de eslora 2:
def coloc_barcos_e1(tablero):
    eslora=1
    i=0
    while i<4:
        # 'N' - 'S' - 'E' - 'O'
        orient = random.choice(['N', 'S', 'E', 'O'])  
        print(orient)
        
        # Posicion inicial del barco, np.array con dos valores, te da las primeras coordenadas
        current_pos = np.random.randint(10, size = 2)
        print('Posición inicial:',current_pos)
        
        fila = current_pos[0]
        print('Fila:', fila)
        col = current_pos[1]
        print('Columna:', col)
        
        # Recogemos las 4 posiciones colindantes a current_pos
        coors_posiN = tablero[fila:fila - eslora:-1, col]
        coors_posiE = tablero[fila, col: col + eslora]
        coors_posiS = tablero[fila:fila + eslora, col]
        coors_posiO = tablero[fila, col: col - eslora:-1]
        
        # Comprobamos si esas posiciones son validas
        # Orientacion Norte
        if orient == 'N' and 0 <= fila - eslora < 10 and 'O' not in coors_posiN:
            tablero[fila:fila - eslora:-1, col] = 'O'
            i+=1
            

        # Orientacion Este
        elif orient == 'E' and 0 <= col + eslora < 10 and 'O' not in coors_posiE:
            tablero[fila, col: col + eslora] = 'O'
            i+=1

        # Orientacion Sur
        elif orient == 'S' and 0 <= fila + eslora < 10 and 'O' not in coors_posiS:
            tablero[fila:fila + eslora, col] = 'O'
            i+=1

        # Orientacion Oeste
        elif orient == 'O' and 0 <= col - eslora < 10 and 'O' not in coors_posiO:
            tablero[fila, col: col - eslora:-1] = 'O'
            i+=1

        # No cumple con las dimensiones del tablero, o hay un barco ahi
        # Probamos con otra coordenada
        else:
            continue
    return tablero


coloc_barcos_e1(tablero_jugador_barcos)
# Out:
# S
# Posición inicial: [5 1]
# Fila: 5
# Columna: 1
# E
# Posición inicial: [9 5]
# Fila: 9
# Columna: 5
# E
# Posición inicial: [3 1]
# Fila: 3
# Columna: 1
# E
# Posición inicial: [4 7]
# Fila: 4
# Columna: 7
# S
# Posición inicial: [0 2]
# Fila: 0
# Columna: 2
# array([[' ', ' ', 'O', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', 'O', 'O', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', 'O', ' ', 'O', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', 'O', ' ', ' ', ' ', 'O', ' ', ' '],
#        ['O', 'O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['O', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'O'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'O'],
#        [' ', ' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O', ' '],
#        [' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O', ' ', ' ']], dtype='<U1')

# %%
def laquesea(tablero):
    coloc_barcos_e1(tablero)
    coloc_barcos_e2(tablero)
    coloc_barcos_e3(tablero)
    coloc_barcos_e4(tablero)
    return tablero

laquesea(tablero_maquina_disparos)
# Out:
# O
# Posición inicial: [2 7]
# Fila: 2
# Columna: 7
# O
# Posición inicial: [0 5]
# Fila: 0
# Columna: 5
# O
# Posición inicial: [9 7]
# Fila: 9
# Columna: 7
# E
# Posición inicial: [0 8]
# Fila: 0
# Columna: 8
# N
# Posición inicial: [8 1]
# Fila: 8
# Columna: 1
# N
# Posición inicial: [1 1]
# Fila: 1
# Columna: 1
# S
# Posición inicial: [7 7]
# Fila: 7
# Columna: 7
# O
# Posición inicial: [9 9]
# Fila: 9
# Columna: 9
# E
# Posición inicial: [3 1]
# Fila: 3
# Columna: 1
# E
# Posición inicial: [4 0]
# Fila: 4
# Columna: 0
# S
# Posición inicial: [8 3]
# Fila: 8
# Columna: 3
# E
# Posición inicial: [3 1]
# Fila: 3
# Columna: 1
# E
# Posición inicial: [9 6]
# Fila: 9
# Columna: 6
# S
# Posición inicial: [2 4]
# Fila: 2
# Columna: 4
# array([[' ', ' ', ' ', ' ', ' ', 'O', ' ', ' ', 'O', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', 'O', ' ', ' ', 'O', ' ', ' '],
#        [' ', 'O', 'O', 'O', 'O', ' ', ' ', ' ', ' ', ' '],
#        ['O', 'O', 'O', ' ', 'O', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', 'O', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', 'O', ' ', ' ', ' ', ' ', ' ', 'O', ' ', ' '],
#        [' ', 'O', ' ', ' ', ' ', ' ', ' ', 'O', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', 'O', 'O', 'O']], dtype='<U1')
